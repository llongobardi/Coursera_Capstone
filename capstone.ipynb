# %% [markdown]
# ## Data Science Capstone
#
# This project is the data science capstone from the Data Science Coursera IBM Course

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
